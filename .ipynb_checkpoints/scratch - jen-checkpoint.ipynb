# %% [markdown]
# ### Initialize

# %%
# Install a few python packages using pip
#from w266_common import utils
#utils.require_package("wget")      # for fetching dataset

# Standard python helper libraries.
import os, sys, re, json, time
import itertools, collections
from importlib import reload
from IPython.display import display

# NumPy and SciPy for matrix ops
import numpy as np
import scipy.sparse

# NLTK for NLP utils
import nltk

# Helper libraries
from w266_common import utils, vocabulary, tf_embed_viz

# from __future__ import print_function, division
#%matplotlib inline
# from matplotlib import pyplot as plt
import random
import debiaswe.debiaswe as dwe
import debiaswe.debiaswe.we as we
from debiaswe.debiaswe.we import WordEmbedding
# from debiaswe.data import load_professions

# %% [markdown]
# ### Import GloVe dataset
# Contains 6B tokens from Wikipedia 2014 + Gigawords 5.
#
# (will take a while to run)

# %%
import glove_helper; reload(glove_helper)

hands = glove_helper.Hands(ndim=100)  # 50, 100, 200, 300 dim are available
# Out:
# Loading vectors from data/glove/glove.6B.zip
# Parsing file: data/glove/glove.6B.zip:glove.6B.100d.txt
# Found 400,000 words.
# Parsing vectors... Done! (W.shape = (400003, 100))

# %%
# April's embedding
E = WordEmbedding("./data/glove/glove.6B/glove.6B.300d.txt") # 50, 100, 200, 300 dim are available
# Out:
# *** Reading data from ./data/glove/glove.6B/glove.6B.300d.txt
# (400000, 300)
# 400000 words of dimension 300 : the, ,, ., of, ..., kronik, rolonda, zsombor, sandberger
# 400000 words of dimension 300 : the, ,, ., of, ..., kronik, rolonda, zsombor, sandberger

# %%
import vector_math; reload(vector_math)

def show_nns(hands, word, k=10):
    """Helper function to print neighbors of a given word."""
    word = word.lower()
    print("Nearest neighbors for '{:s}'".format(word))
    v = hands.get_vector(word)
    for i, sim in zip(*vector_math.find_nn_cos(v, hands.W, k)):
        target_word = hands.vocab.id_to_word[i]
        print("{:.03f} : '{:s}'".format(sim, target_word))
    print("")
    
def show_analogy(hands, a, b, c, k=5):
    """Compute and print a vector analogy."""
    a, b, c = a.lower(), b.lower(), c.lower()
    va = hands.get_vector(a)
    vb = hands.get_vector(b)
    vc = hands.get_vector(c)
    print("'{a:s}' is to '{b:s}' as '{c:s}' is to ___".format(**locals()))
    for i, sim in zip(*vector_math.analogy(va, vb, vc, hands.W, k)):
        target_word = hands.vocab.id_to_word[i]
        print("{:.03f} : '{:s}'".format(sim, target_word))
    print("")

# %%
show_nns(hands, "democrat", 5)
show_nns(hands, "liberal", 5)
show_nns(hands, "progressive", 5)


show_nns(hands, "republican", 5)
show_nns(hands, "conservative", 5)
# Out:
# Nearest neighbors for 'democrat'
# 0.809 : 'sen.'
# 0.812 : 'democratic'
# 0.864 : 'senator'
# 0.879 : 'republican'
# 1.000 : 'democrat'
#
# Nearest neighbors for 'liberal'
# 0.781 : 'centrist'
# 0.801 : 'liberals'
# 0.820 : 'conservatives'
# 0.935 : 'conservative'
# 1.000 : 'liberal'
#
# Nearest neighbors for 'progressive'
# 0.645 : 'party'
# 0.666 : 'democratic'
# 0.676 : 'conservative'
# 0.754 : 'liberal'
# 1.000 : 'progressive'
#
# Nearest neighbors for 'republican'
# 0.871 : 'republicans'
# 0.874 : 'democratic'
# 0.879 : 'democrat'
# 0.931 : 'gop'
# 1.000 : 'republican'
#
# Nearest neighbors for 'conservative'
# 0.750 : 'democratic'
# 0.766 : 'republican'
# 0.838 : 'conservatives'
# 0.935 : 'liberal'
# 1.000 : 'conservative'

# %%
show_analogy(hands, "democrat", "republican", "liberal") # works
show_analogy(hands, "democrat", "republican", "liberalism") # works
show_analogy(hands, "democrat", "republican", "progressive") # works
show_analogy(hands, "democrat", "republican", "anti-federalist") # works
show_analogy(hands, "democrat", "republican", "left-wing") # works
show_analogy(hands, "democrat", "republican", "left-of-center") # works
show_analogy(hands, "democrat", "republican", "left-leaning") # works
show_analogy(hands, "democrat", "republican", "far-left") # works
# Out:
# 'democrat' is to 'republican' as 'liberal' is to ___
# 0.732 : 'democratic'
# 0.749 : 'republican'
# 0.798 : 'conservatives'
# 0.891 : 'conservative'
# 0.892 : 'liberal'
#
# 'democrat' is to 'republican' as 'liberalism' is to ___
# 0.678 : 'republicanism'
# 0.680 : 'orthodoxy'
# 0.681 : 'ideology'
# 0.789 : 'conservatism'
# 0.850 : 'liberalism'
#
# 'democrat' is to 'republican' as 'progressive' is to ___
# 0.639 : 'party'
# 0.661 : 'conservative'
# 0.663 : 'democratic'
# 0.670 : 'liberal'
# 0.886 : 'progressive'
#
# 'democrat' is to 'republican' as 'anti-federalist' is to ___
# 0.563 : 'anticlerical'
# 0.566 : 'anti-papal'
# 0.588 : 'anti-qing'
# 0.615 : 'austro-german'
# 0.756 : 'anti-federalist'
#
# 'democrat' is to 'republican' as 'left-wing' is to ___
# 0.658 : 'left-leaning'
# 0.668 : 'pro-independence'
# 0.675 : 'far-right'
# 0.821 : 'right-wing'
# 0.867 : 'left-wing'
#
# 'democrat' is to 'republican' as 'left-of-center' is to ___
# 0.583 : 'foreign-based'
# 0.587 : 'pro-republican'
# 0.587 : 'left-liberal'
# 0.649 : 'left-of-centre'
# 0.705 : 'left-of-center'
#
# 'democrat' is to 'republican' as 'left-leaning' is to ___
# 0.610 : 'pro-war'
# 0.612 : 'right-leaning'
# 0.637 : 'right-wing'
# 0.672 : 'left-wing'
# 0.768 : 'left-leaning'
#
# 'democrat' is to 'republican' as 'far-left' is to ___
# 0.614 : 'left-wing'
# 0.619 : 'independentist'
# 0.636 : 'far-right'
# 0.662 : 'neo-fascist'
# 0.785 : 'far-left'

# %%
show_analogy(hands, "democrat", "republican", "liberal") # works

# education
show_analogy(hands, "democrat", "republican", "education")

show_analogy(hands, "democrat", "republican", "educated")

show_analogy(hands, "democrat", "republican", "graduate")

show_analogy(hands, "democrat", "republican", "college")

show_analogy(hands, "democrat", "republican", "university")

show_analogy(hands, "democrat", "republican", "intelligent")

show_analogy(hands, "democrat", "republican", "blue-collar") 

show_analogy(hands, "republican"# !!!

show_analogy(hands, "democrat", "republican", "employed")

show_analogy(hands, "democrat", "republican", "elitist") # !!!

show_analogy(hands, "democrat", "republican", "union")

# race

show_analogy(hands, "democrat", "republican", "minorities")

show_analogy(hands, "democrat", "republican", "african-american")

show_analogy(hands, "democrat", "republican", "hispanic")

show_analogy(hands, "democrat", "republican", "latino")

show_analogy(hands, "democrat", "republican", "immigrant")

# religion

show_analogy(hands, "democrat", "republican", "atheist")

show_analogy(hands, "democrat", "republican", "agnostic")

# gender

show_analogy(hands, "democrat", "republican", "woman") # !!!


# misc demographics




show_analogy(hands, "democrat", "republican", "youth")

show_analogy(hands, "democrat", "republican", "young")             

show_analogy(hands, "democrat", "republican", "hippie")

show_analogy(hands, "democrat", "republican", "naive")

show_analogy(hands, "democrat", "republican", "kind")

show_analogy(hands, "democrat", "republican", "peace")

show_analogy(hands, "democrat", "republican", "socialist")
# Out:
# 'democrat' is to 'republican' as 'liberal' is to ___
# 0.732 : 'democratic'
# 0.749 : 'republican'
# 0.798 : 'conservatives'
# 0.891 : 'conservative'
# 0.892 : 'liberal'
#
# 'democrat' is to 'republican' as 'education' is to ___
# 0.732 : 'funding'
# 0.773 : 'schools'
# 0.781 : 'programs'
# 0.806 : 'educational'
# 0.904 : 'education'
#
# 'democrat' is to 'republican' as 'educated' is to ___
# 0.605 : 'students'
# 0.610 : 'young'
# 0.613 : 'trained'
# 0.620 : 'younger'
# 0.878 : 'educated'
#
# 'democrat' is to 'republican' as 'graduate' is to ___
# 0.746 : 'students'
# 0.757 : 'faculty'
# 0.766 : 'college'
# 0.797 : 'undergraduate'
# 0.887 : 'graduate'
#
# 'democrat' is to 'republican' as 'college' is to ___
# 0.713 : 'colleges'
# 0.721 : 'schools'
# 0.741 : 'university'
# 0.823 : 'school'
# 0.913 : 'college'
#
# 'democrat' is to 'republican' as 'university' is to ___
# 0.733 : 'school'
# 0.743 : 'faculty'
# 0.744 : 'harvard'
# 0.791 : 'college'
# 0.918 : 'university'
#
# 'democrat' is to 'republican' as 'intelligent' is to ___
# 0.629 : 'highly'
# 0.635 : 'thoughtful'
# 0.654 : 'smart'
# 0.671 : 'sophisticated'
# 0.862 : 'intelligent'
#
# 'democrat' is to 'republican' as 'white-collar' is to ___
# 0.518 : 'occupations'
# 0.520 : 'low-skilled'
# 0.547 : 'low-paid'
# 0.672 : 'blue-collar'
# 0.819 : 'white-collar'
#
# 'democrat' is to 'republican' as 'employed' is to ___
# 0.659 : 'employing'
# 0.662 : 'used'
# 0.678 : 'primarily'
# 0.687 : 'employ'
# 0.852 : 'employed'
#
# 'democrat' is to 'republican' as 'elitist' is to ___
# 0.592 : 'overtly'
# 0.625 : 'anachronistic'
# 0.629 : 'misguided'
# 0.629 : 'hypocritical'
# 0.848 : 'elitist'
#
# 'democrat' is to 'republican' as 'union' is to ___
# 0.666 : 'nations'
# 0.676 : 'leaders'
# 0.692 : 'members'
# 0.716 : 'unions'
# 0.905 : 'union'
#
# 'democrat' is to 'republican' as 'minorities' is to ___
# 0.651 : 'groups'
# 0.654 : 'muslims'
# 0.695 : 'ethnic'
# 0.738 : 'minority'
# 0.892 : 'minorities'
#
# 'democrat' is to 'republican' as 'african-american' is to ___
# 0.577 : 'female'
# 0.589 : 'african-americans'
# 0.598 : 'american'
# 0.618 : 'hispanic'
# 0.874 : 'african-american'
#
# 'democrat' is to 'republican' as 'hispanic' is to ___
# 0.623 : 'voters'
# 0.671 : 'latinos'
# 0.724 : 'hispanics'
# 0.833 : 'latino'
# 0.905 : 'hispanic'
#
# 'democrat' is to 'republican' as 'latino' is to ___
# 0.585 : 'voters'
# 0.657 : 'latinos'
# 0.665 : 'hispanics'
# 0.863 : 'hispanic'
# 0.895 : 'latino'
#
# 'democrat' is to 'republican' as 'immigrant' is to ___
# 0.618 : 'families'
# 0.620 : 'americans'
# 0.632 : 'migrant'
# 0.745 : 'immigrants'
# 0.862 : 'immigrant'
#
# 'democrat' is to 'republican' as 'atheist' is to ___
# 0.558 : 'evangelical'
# 0.562 : 'atheism'
# 0.569 : 'atheistic'
# 0.664 : 'agnostic'
# 0.875 : 'atheist'
#
# 'democrat' is to 'republican' as 'agnostic' is to ___
# 0.484 : 'altruistic'
# 0.485 : 'anathema'
# 0.538 : 'adherent'
# 0.753 : 'atheist'
# 0.892 : 'agnostic'
#
# 'democrat' is to 'republican' as 'woman' is to ___
# 0.732 : 'her'
# 0.736 : 'female'
# 0.742 : 'girl'
# 0.757 : 'man'
# 0.883 : 'woman'
#
# 'democrat' is to 'republican' as 'gay' is to ___
# 0.645 : 'sex'
# 0.660 : 'homosexual'
# 0.661 : 'gays'
# 0.756 : 'lesbian'
# 0.904 : 'gay'
#
# 'democrat' is to 'republican' as 'lesbian' is to ___
# 0.678 : 'transgender'
# 0.680 : 'bisexual'
# 0.714 : 'lgbt'
# 0.807 : 'gay'
# 0.880 : 'lesbian'
#
# 'democrat' is to 'republican' as 'transgender' is to ___
# 0.707 : 'transgendered'
# 0.743 : 'bisexual'
# 0.760 : 'lesbian'
# 0.804 : 'lgbt'
# 0.872 : 'transgender'
#
# 'democrat' is to 'republican' as 'bisexual' is to ___
# 0.677 : 'gay'
# 0.697 : 'lgbt'
# 0.743 : 'transgender'
# 0.764 : 'lesbian'
# 0.866 : 'bisexual'
#
# 'democrat' is to 'republican' as 'homosexual' is to ___
# 0.683 : 'sex'
# 0.697 : 'gay'
# 0.721 : 'sexual'
# 0.732 : 'heterosexual'
# 0.888 : 'homosexual'
#
# 'democrat' is to 'republican' as 'youth' is to ___
# 0.649 : 'groups'
# 0.651 : 'participation'
# 0.652 : 'community'
# 0.655 : 'activities'
# 0.875 : 'youth'
#
# 'democrat' is to 'republican' as 'young' is to ___
# 0.685 : 'few'
# 0.697 : 'among'
# 0.722 : 'many'
# 0.735 : 'younger'
# 0.893 : 'young'
#
# 'democrat' is to 'republican' as 'hippie' is to ___
# 0.586 : 'hipster'
# 0.613 : ''70s'
# 0.630 : ''60s'
# 0.680 : 'counterculture'
# 0.838 : 'hippie'
#
# 'democrat' is to 'republican' as 'naive' is to ___
# 0.685 : 'unrealistic'
# 0.702 : 'foolish'
# 0.707 : 'cynical'
# 0.791 : 'misguided'
# 0.845 : 'naive'
#
# 'democrat' is to 'republican' as 'kind' is to ___
# 0.783 : 'even'
# 0.791 : 'something'
# 0.792 : 'nothing'
# 0.872 : 'sort'
# 0.891 : 'kind'
#
# 'democrat' is to 'republican' as 'peace' is to ___
# 0.726 : 'conflict'
# 0.729 : 'cease'
# 0.744 : 'reconciliation'
# 0.746 : 'truce'
# 0.927 : 'peace'
#
# 'democrat' is to 'republican' as 'socialist' is to ___
# 0.695 : 'opposition'
# 0.704 : 'democratic'
# 0.734 : 'communist'
# 0.744 : 'party'
# 0.882 : 'socialist'

# %%
# education
show_analogy(hands, "democrat", "republican", "higher-education")

show_analogy(hands, "democrat", "republican", "college")

show_analogy(hands, "democrat", "republican", "university")

show_analogy(hands, "democrat", "republican", "intelligent")

show_analogy(hands, "democrat", "republican", "scholar")

show_analogy(hands, "democrat", "republican", "phd")

show_analogy(hands, "democrat", "republican", "blue-collar") # !!

show_analogy(hands, "democrat", "republican", "employed")

show_analogy(hands, "democrat", "republican", "elitist") # !!!

show_analogy(hands, "democrat", "republican", "union")

show_analogy(hands, "republican", "democrat", "uneducated")

show_analogy(hands, "republican", "democrat", "uneducated")
# Out:
# 'democrat' is to 'republican' as 'higher-education' is to ___
# 0.558 : 'religious-based'
# 0.559 : 'college-based'
# 0.562 : 'bio-weapons'
# 0.571 : 'deposit-taking'
# 0.792 : 'higher-education'
#
# 'democrat' is to 'republican' as 'college' is to ___
# 0.713 : 'colleges'
# 0.721 : 'schools'
# 0.741 : 'university'
# 0.823 : 'school'
# 0.913 : 'college'
#
# 'democrat' is to 'republican' as 'university' is to ___
# 0.733 : 'school'
# 0.743 : 'faculty'
# 0.744 : 'harvard'
# 0.791 : 'college'
# 0.918 : 'university'
#
# 'democrat' is to 'republican' as 'intelligent' is to ___
# 0.629 : 'highly'
# 0.635 : 'thoughtful'
# 0.654 : 'smart'
# 0.671 : 'sophisticated'
# 0.862 : 'intelligent'
#
# 'democrat' is to 'republican' as 'scholar' is to ___
# 0.631 : 'literary'
# 0.632 : 'literature'
# 0.701 : 'historian'
# 0.766 : 'scholars'
# 0.882 : 'scholar'
#
# 'democrat' is to 'republican' as 'phd' is to ___
# 0.792 : 'doctorate'
# 0.810 : 'doctoral'
# 0.816 : 'ph.d'
# 0.827 : 'ph.d.'
# 0.878 : 'phd'
#
# 'democrat' is to 'republican' as 'blue-collar' is to ___
# 0.520 : 'low-paid'
# 0.537 : 'nonunion'
# 0.546 : 'non-union'
# 0.564 : 'working-class'
# 0.811 : 'blue-collar'
#
# 'democrat' is to 'republican' as 'employed' is to ___
# 0.659 : 'employing'
# 0.662 : 'used'
# 0.678 : 'primarily'
# 0.687 : 'employ'
# 0.852 : 'employed'
#
# 'democrat' is to 'republican' as 'elitist' is to ___
# 0.592 : 'overtly'
# 0.625 : 'anachronistic'
# 0.629 : 'misguided'
# 0.629 : 'hypocritical'
# 0.848 : 'elitist'
#
# 'democrat' is to 'republican' as 'union' is to ___
# 0.666 : 'nations'
# 0.676 : 'leaders'
# 0.692 : 'members'
# 0.716 : 'unions'
# 0.905 : 'union'
#
# 'republican' is to 'democrat' as 'uneducated' is to ___
# 0.593 : 'unskilled'
# 0.649 : 'underemployed'
# 0.701 : 'undereducated'
# 0.728 : 'illiterate'
# 0.870 : 'uneducated'

# %%
# race

show_analogy(hands, "democrat", "republican", "african-american")

show_analogy(hands, "democrat", "republican", "black")

show_analogy(hands, "democrat", "republican", "latino")

show_analogy(hands, "democrat", "republican", "hispanic")

show_analogy(hands, "democrat", "republican", "oppressed")

show_analogy(hands, "democrat", "republican", "immigrants")
# Out:
# 'democrat' is to 'republican' as 'african-american' is to ___
# 0.577 : 'female'
# 0.589 : 'african-americans'
# 0.598 : 'american'
# 0.618 : 'hispanic'
# 0.874 : 'african-american'
#
# 'democrat' is to 'republican' as 'woman' is to ___
# 0.732 : 'her'
# 0.736 : 'female'
# 0.742 : 'girl'
# 0.757 : 'man'
# 0.883 : 'woman'
#
# 'democrat' is to 'republican' as 'black' is to ___
# 0.676 : 'dark'
# 0.696 : 'blue'
# 0.704 : 'red'
# 0.821 : 'white'
# 0.900 : 'black'
#
# 'democrat' is to 'republican' as 'latino' is to ___
# 0.585 : 'voters'
# 0.657 : 'latinos'
# 0.665 : 'hispanics'
# 0.863 : 'hispanic'
# 0.895 : 'latino'
#
# 'democrat' is to 'republican' as 'hispanic' is to ___
# 0.623 : 'voters'
# 0.671 : 'latinos'
# 0.724 : 'hispanics'
# 0.833 : 'latino'
# 0.905 : 'hispanic'
#
# 'democrat' is to 'republican' as 'oppressed' is to ___
# 0.608 : 'marginalised'
# 0.609 : 'disenfranchised'
# 0.639 : 'marginalized'
# 0.645 : 'persecuted'
# 0.880 : 'oppressed'
#
# 'democrat' is to 'republican' as 'immigrants' is to ___
# 0.703 : 'immigrant'
# 0.714 : 'foreigners'
# 0.724 : 'americans'
# 0.758 : 'migrants'
# 0.892 : 'immigrants'

# %%
# demographics 

show_analogy(hands, "democrat", "republican", "woman")

show_analogy(hands, "republican", "democrat", "redneck")

show_analogy(hands, "republican", "democrat", "southern")

show_analogy(hands, "republican", "democrat", "pro-life")

show_analogy(hands, "republican", "democrat", "elderly")

show_analogy(hands, "republican", "democrat", "older")
# Out:
# 'democrat' is to 'republican' as 'woman' is to ___
# 0.732 : 'her'
# 0.736 : 'female'
# 0.742 : 'girl'
# 0.757 : 'man'
# 0.883 : 'woman'
#
# 'republican' is to 'democrat' as 'redneck' is to ___
# 0.512 : 'surfer'
# 0.524 : 'scoundrel'
# 0.525 : 'tomboy'
# 0.578 : 'dude'
# 0.817 : 'redneck'
#
# 'republican' is to 'democrat' as 'southern' is to ___
# 0.767 : 'southwestern'
# 0.770 : 'eastern'
# 0.805 : 'northeastern'
# 0.818 : 'northern'
# 0.872 : 'southern'
#
# 'republican' is to 'democrat' as 'pro-life' is to ___
# 0.519 : 'suffragette'
# 0.550 : 'suffragist'
# 0.573 : 'anti-abortion'
# 0.739 : 'pro-choice'
# 0.835 : 'pro-life'
#
# 'republican' is to 'democrat' as 'elderly' is to ___
# 0.621 : 'homeless'
# 0.631 : 'pregnant'
# 0.634 : 'handicapped'
# 0.658 : 'unemployed'
# 0.860 : 'elderly'
#
# 'republican' is to 'democrat' as 'older' is to ___
# 0.587 : 'daughter'
# 0.596 : 'aged'
# 0.653 : 'age'
# 0.706 : 'younger'
# 0.848 : 'older'

# %%
# religion 

show_analogy(hands, "democrat", "republican", "secular")

show_analogy(hands, "democrat", "republican", "atheist")
show_analogy(hands, "democrat", "republican", "agnostic")

show_analogy(hands, "republican", "democrat", "evangelical")
show_analogy(hands, "republican", "democrat", "christian")
show_analogy(hands, "republican", "democrat", "religious")
# Out:
# 'democrat' is to 'republican' as 'secular' is to ___
# 0.667 : 'shiite'
# 0.686 : 'fundamentalist'
# 0.712 : 'islamic'
# 0.790 : 'religious'
# 0.904 : 'secular'
#
# 'democrat' is to 'republican' as 'atheist' is to ___
# 0.558 : 'evangelical'
# 0.562 : 'atheism'
# 0.569 : 'atheistic'
# 0.664 : 'agnostic'
# 0.875 : 'atheist'
#
# 'democrat' is to 'republican' as 'agnostic' is to ___
# 0.484 : 'altruistic'
# 0.485 : 'anathema'
# 0.538 : 'adherent'
# 0.753 : 'atheist'
# 0.892 : 'agnostic'
#
# 'republican' is to 'democrat' as 'evangelical' is to ___
# 0.657 : 'christian'
# 0.661 : 'presbyterian'
# 0.717 : 'pentecostal'
# 0.774 : 'lutheran'
# 0.855 : 'evangelical'
#
# 'republican' is to 'democrat' as 'christian' is to ___
# 0.598 : 'orthodox'
# 0.627 : 'lutheran'
# 0.650 : 'evangelical'
# 0.671 : 'catholic'
# 0.874 : 'christian'
#
# 'republican' is to 'democrat' as 'religious' is to ___
# 0.680 : 'christian'
# 0.686 : 'muslim'
# 0.712 : 'secular'
# 0.732 : 'religion'
# 0.872 : 'religious'

# %%
show_nns(hands, "yda")
# Out:
# Nearest neighbors for 'yda'
# 0.720 : 'ibba'
# 0.720 : 'uwsp'
# 0.720 : 'ntcc'
# 0.723 : 'icss'
# 0.724 : 'nlgja'
# 0.731 : 'apda'
# 0.737 : 'iaba'
# 0.738 : 'aarc'
# 0.756 : 'jacl'
# 1.000 : 'yda'

# %%
# sexuality

show_analogy(hands, "democrat", "republican", "gay")

show_analogy(hands, "democrat", "republican", "lesbian")

show_analogy(hands, "democrat", "republican", "transgender")

show_analogy(hands, "democrat", "republican", "bisexual")

show_analogy(hands, "democrat", "republican", "homosexual") # !!!
# Out:
# 'democrat' is to 'republican' as 'gay' is to ___
# 0.645 : 'sex'
# 0.660 : 'homosexual'
# 0.661 : 'gays'
# 0.756 : 'lesbian'
# 0.904 : 'gay'
#
# 'democrat' is to 'republican' as 'lesbian' is to ___
# 0.678 : 'transgender'
# 0.680 : 'bisexual'
# 0.714 : 'lgbt'
# 0.807 : 'gay'
# 0.880 : 'lesbian'
#
# 'democrat' is to 'republican' as 'transgender' is to ___
# 0.707 : 'transgendered'
# 0.743 : 'bisexual'
# 0.760 : 'lesbian'
# 0.804 : 'lgbt'
# 0.872 : 'transgender'
#
# 'democrat' is to 'republican' as 'bisexual' is to ___
# 0.677 : 'gay'
# 0.697 : 'lgbt'
# 0.743 : 'transgender'
# 0.764 : 'lesbian'
# 0.866 : 'bisexual'
#
# 'democrat' is to 'republican' as 'homosexual' is to ___
# 0.683 : 'sex'
# 0.697 : 'gay'
# 0.721 : 'sexual'
# 0.732 : 'heterosexual'
# 0.888 : 'homosexual'

# %%
# income / work
show_analogy(hands, "democrat", "republican", "poor")
show_analogy(hands, "democrat", "republican", "lower-class")
show_analogy(hands, "democrat", "republican", "union")
show_analogy(hands, "democrat", "republican", "unionized")
show_analogy(hands, "democrat", "republican", "welfare")

show_analogy(hands, "republican", "democrat", "wealthy")
show_analogy(hands, "republican", "democrat", "rich")
show_analogy(hands, "republican", "democrat", "upper-class")
show_analogy(hands, "republican", "democrat", "high-class")
show_analogy(hands, "republican", "democrat", "nonunion")
show_analogy(hands, "republican", "democrat", "non-union")
# Out:
# 'democrat' is to 'republican' as 'poor' is to ___
# 0.689 : 'many'
# 0.699 : 'especially'
# 0.705 : 'because'
# 0.725 : 'lack'
# 0.893 : 'poor'
#
# 'democrat' is to 'republican' as 'lower-class' is to ___
# 0.561 : 'middle-class'
# 0.577 : 'lower-income'
# 0.591 : 'nonreligious'
# 0.601 : 'upper-class'
# 0.782 : 'lower-class'
#
# 'democrat' is to 'republican' as 'union' is to ___
# 0.666 : 'nations'
# 0.676 : 'leaders'
# 0.692 : 'members'
# 0.716 : 'unions'
# 0.905 : 'union'
#
# 'democrat' is to 'republican' as 'unionized' is to ___
# 0.603 : 'salaried'
# 0.631 : 'workers'
# 0.663 : 'employees'
# 0.757 : 'nonunion'
# 0.878 : 'unionized'
#
# 'democrat' is to 'republican' as 'welfare' is to ___
# 0.693 : 'funding'
# 0.700 : 'reform'
# 0.714 : 'benefits'
# 0.716 : 'spending'
# 0.884 : 'welfare'
#
# 'republican' is to 'democrat' as 'wealthy' is to ___
# 0.595 : 'well-to-do'
# 0.597 : 'banker'
# 0.643 : 'wealthiest'
# 0.678 : 'affluent'
# 0.874 : 'wealthy'
#
# 'republican' is to 'democrat' as 'rich' is to ___
# 0.513 : 'richest'
# 0.521 : 'mineral'
# 0.536 : 'wealthy'
# 0.550 : 'richer'
# 0.862 : 'rich'
#
# 'republican' is to 'democrat' as 'upper-class' is to ___
# 0.625 : 'middle-aged'
# 0.636 : 'lower-class'
# 0.668 : 'upper-middle-class'
# 0.682 : 'middle-class'
# 0.822 : 'upper-class'
#
# 'republican' is to 'democrat' as 'high-class' is to ___
# 0.522 : 'becco'
# 0.523 : 'bourgeoise'
# 0.525 : 'harijan'
# 0.557 : 'sharp-tongued'
# 0.741 : 'high-class'
#
# 'republican' is to 'democrat' as 'nonunion' is to ___
# 0.570 : 'low-wage'
# 0.607 : 'unskilled'
# 0.626 : 'non-union'
# 0.704 : 'unionized'
# 0.837 : 'nonunion'
#
# 'republican' is to 'democrat' as 'non-union' is to ___
# 0.522 : 'blue-collar'
# 0.528 : 'low-skilled'
# 0.585 : 'low-wage'
# 0.642 : 'semi-skilled'
# 0.796 : 'non-union'

# %%
show_nns(hands, "homosexual")

show_nns(hands, "man")

show_nns(hands, "southern")
# Out:
# Nearest neighbors for 'homosexual'
# 0.691 : 'bisexual'
# 0.694 : 'lesbians'
# 0.720 : 'lesbian'
# 0.720 : 'homosexuals'
# 0.740 : 'gay'
# 0.740 : 'homosexuality'
# 0.748 : 'sex'
# 0.754 : 'sexual'
# 0.820 : 'heterosexual'
# 1.000 : 'homosexual'
#
# Nearest neighbors for 'man'
# 0.735 : 'turned'
# 0.737 : 'father'
# 0.737 : 'life'
# 0.741 : 'old'
# 0.752 : 'another'
# 0.753 : 'person'
# 0.779 : 'one'
# 0.791 : 'boy'
# 0.832 : 'woman'
# 1.000 : 'man'
#
# Nearest neighbors for 'southern'
# 0.793 : 'southwest'
# 0.808 : 'northwest'
# 0.823 : 'northwestern'
# 0.839 : 'southwestern'
# 0.848 : 'southeastern'
# 0.851 : 'western'
# 0.864 : 'northeastern'
# 0.887 : 'eastern'
# 0.936 : 'northern'
# 1.000 : 'southern'

# %%
# April's direction calc
# democrat-republican gender direction on GloVe
party_direction = E.diff("democrat", "republican")

# appendix A: generating analogies
party_analogies = E.best_analogies_dist_thresh(party_direction)
# Out:
# /Users/jenniferpodracky/anaconda3/lib/python3.6/site-packages/numpy/linalg/linalg.py:2257: RuntimeWarning: invalid value encountered in sqrt
#   ret = sqrt(sqnorm)

# %%
# liberal-conservative direction on GloVe
lean_direction = E.diff("liberal", "conservative")

# appendix A: generating analogies
lean_analogies = E.best_analogies_dist_thresh(lean_direction)
# Out:
# /Users/jenniferpodracky/anaconda3/lib/python3.6/site-packages/numpy/linalg/linalg.py:2257: RuntimeWarning: invalid value encountered in sqrt
#   ret = sqrt(sqnorm)
# Computing neighbors
# Mean: 21.39444
# Median: 4.0
# /Users/jenniferpodracky/Documents/MIDS/w266/w266-2018-summer-final-biased-word-embeddings/debiaswe/debiaswe/we.py:139: RuntimeWarning: divide by zero encountered in true_divide
#   self._neighbors = rows, cols, np.array([v/np.linalg.norm(v) for v in vecs])
# /Users/jenniferpodracky/Documents/MIDS/w266/w266-2018-summer-final-biased-word-embeddings/debiaswe/debiaswe/we.py:139: RuntimeWarning: invalid value encountered in true_divide
#   self._neighbors = rows, cols, np.array([v/np.linalg.norm(v) for v in vecs])

# %%
# print party analogies
for (a,b,c) in party_analogies:
    print(a+"-"+b)
# Out:
# ,-the
# 35.2-23.5
# cheddar-cheeses
# taoiseach-fianna
# evocative-descriptive
# stinking-filthy
# ridiculously-awfully
# potable-wastewater
# usair-ual
# laborious-painstaking
# 86-year-62-year
# millwall-brom
# 286-274
# welder-electrician
# marxists-anarchists
# domesticated-turkeys
# overline-sted
# beaujolais-nouveau
# aggressions-provocations
# abuzz-buzzing
# undead-zombies
# bjarne-csc
# mandolin-banjo
# solidifying-solidify
# boisterous-joyous
# peeking-poking
# reissues-reissue
# jogged-limped
# scooping-scooped
# overvalued-valuations
# muffled-audible
# 1563-1530
# 85-year-58-year
# photovoltaic-pv
# aqueous-acidic
# paraná-río
# 107th-81st
# newborns-toddlers
# ovaries-womb
# fossilized-footprints
# f-14-hornet
# horticulture-horticultural
# commutes-commuting
# silhouettes-silhouette
# signified-signifies
# santorum-brownback
# blizzards-snowstorm
# synonyms-synonym
# wariness-aversion
# otters-otter
# 355-239
# razzano-schiavone
# truffles-caviar
# fastened-strap
# sleigh-reindeer
# blackmailed-tricked
# diverging-divergent
# hilda-solis
# unflinching-uncompromising
# artfully-meticulously
# 1130-0900
# golovin-dokic
# tsb-rbs
# real-world-real-life
# demurred-hesitated
# vices-evils
# implantation-fertilization
# jarrod-washburn
# umbilical-cords
# livid-incensed
# vasser-indycar
# dior-hermes
# substandard-shoddy
# ebullient-boisterous
# tuqiri-brumbies
# 1715-1772
# kashgar-uygur
# campy-spoof
# interacted-interacting
# keem-rih
# infuse-infused
# shipwrecked-seamen
# faure-gnassingbe
# tangent-perpendicular
# doggedly-stubbornly
# anxieties-soothe
# '92-'96
# alkali-salts
# palme-d'or
# cagney-lacey
# diwaniyah-nasiriyah
# cafeterias-dormitories
# steamers-paddle
# ludacris-snoop
# apologise-apologizing
# two-year-old-sire
# tutors-mentors
# 2.97-0.26
# 2019-2017
# indefatigable-tireless
# ducal-princely
# infused-steeped
# haneya-zahar
# talmud-qur
# quartets-quintet
# 7-12-1-5
# nevis-kitts
# emmys-grammys
# entailed-entails
# jibril-dahlan
# tiberius-nero
# hyperactivity-bipolar
# bichette-helton
# abstaining-abstain
# estrangement-alienation
# ashkelon-sderot
# shakers-movers
# scented-aroma
# raccoons-foxes
# neb.-kerrey
# arugula-cilantro
# 2010-2011-2007-08
# fortuyn-pim
# saloons-brothels
# libertad-cerro
# despot-tyrant
# fillet-steaks
# drunkenness-disorderly
# 33.1-24.5
# libertarians-feminists
# cartoonish-caricature
# unremitting-unrelenting
# trainee-trainees
# britten-requiem
# aniston-affleck
# b.s.-bs
# assimilate-assimilation
# arranger-lyricist
# manet-monet
# ascertained-ascertain
# hanescu-gasquet
# deepak-chopra
# cosmodrome-kazakstan
# normalisation-normalize
# hsiao-hou
# recitals-recital
# infuriating-angering
# pituitary-glands
# drinker-drinkers
# hera-zeus
# midler-keaton
# nair-mira
# flips-flipping
# harpsichord-accordion
# bolsheviks-bolshevik
# o'gara-flyhalf
# curing-cures
# epoxy-resin
# apocryphal-gospels
# endocrine-gland
# castleford-warrington
# figurative-abstraction
# euro25-euro8
# aspired-aspire
# rhett-scarlett
# sturm-graz
# chiseled-sculpted
# 725-237
# carcinoma-ovarian
# possessive-adjective
# nudging-nudge
# approachable-likable
# cruzeiro-palmeiras
# druh-rahk
# swarms-hordes
# 270,000-34,000
# mattingly-boggs
# 4.40-1.27
# rooster-crows
# eskimos-cfl
# kilogrammes-hashish
# atchison-topeka
# unassailable-unbeatable
# delicately-subtly
# madan-mohan
# camdessus-wolfensohn
# exonerate-exonerated
# u-boats-battleships
# othello-macbeth
# 1500m-speedskating
# 26.95-7.50
# distaste-fondness
# torrents-deluge
# uncontrollable-uncontrolled
# fayetteville-ark.
# ajaccio-grenoble
# 106th-74th
# 405-720
# mascots-nicknames
# salacious-scandalous
# madeira-azores
# 609-244
# diligent-conscientious
# lps-eps
# enchanting-unforgettable
# mondale-dukakis
# ís-í
# 0.92-1.85
# frighten-dissuade
# springtime-summertime
# 0.36-1.18
# uyghur-turkic
# rags-rag
# envisage-foresees
# medford-ashland
# vuelta-d'italia
# widens-narrows
# 74th-73rd
# emits-consumes
# speeded-expedite
# maybank-bhd.
# persuades-begs
# neuronal-differentiation
# kamchatka-sakhalin
# seok-hwan
# unconscionable-egregious
# hurdler-400-meter
# resourceful-tenacious
# mildew-stains
# cornstarch-zest
# inserting-attaching
# defiantly-resolutely
# rubs-rubbed
# xing-xia
# goodell-tagliabue
# firebombs-lobbed
# secs-clocking
# horrifying-unimaginable
# delirious-giddy
# sykes-wanda
# prescribes-specifies
# diagnosing-diagnose
# syntactic-semantic
# nationalize-nationalization
# drugstores-pharmacists
# propellers-boilers
# artd-toder
# agility-durability
# vandalized-ransacked
# 12-10-tiebreak
# abilene-lubbock
# sabotaging-wrecking
# femme-nikita
# mountaineer-mountaineers
# prowl-roamed
# 2.54-1.16
# voip-handsets
# blinking-blink
# 16.4-14.2
# 463-261
# guimaraes-braga
# janica-ivica
# heartening-sobering
# obliquely-alluded
# popularizing-inventing
# 11-13-9-11
# petitioner-habeas
# sayings-quotations
# barged-sneaked
# grandstand-bleachers
# formula_7-α
# eilat-aqaba
# decayed-rotting
# compositional-stylistic
# provincetown-nantucket
# 13/16-1/16
# uhf-analogue
# mutilation-circumcision
# damping-vibration
# cingular-at&t
# harkin-baucus
# subsets-formula_6
# valedictorian-laude
# completions-tds
# fellowships-fulbright
# revolts-uprisings
# tue-thu
# wiesel-elie
# foresees-anticipates
# lowlands-grasslands
# 1.52-1.10
# tolerable-permissible
# practicality-usefulness
# levant-mesopotamia
# 99th-85th
# 22.95-hyperion
# connacht-ó
# dolce-vita
# allegiances-loyalties
# baran-yadav
# librarians-curators
# risque-suggestive
# oxidized-oxidation
# 3.21-1.14
# wil-cordero
# finalizing-finalised
# 1772-1774
# eunice-shriver
# eatery-deli
# stevenage-swindon
# camry-minivans
# unitarian-congregational
# anthropomorphic-mythological
# turrets-aft
# overflowed-overflowing
# rewrote-rewritten
# syrah-chardonnay
# modernised-overhauled
# worshipping-worshipped
# 430,000-42,000
# nimble-agile
# heartache-heartbreak
# confederates-repulsed
# federalists-federalist
# premiering-debuting
# fédération-internationale
# auditioning-auditioned
# razors-scissors
# platters-platter
# disquiet-apprehension
# unreasonably-unnecessarily
# terminates-terminating
# distinctively-strikingly
# chiu-tien
# bozize-deby
# preclude-entail
# translucent-opaque
# longest-running-long-running
# perishable-foodstuffs
# coinage-minted
# extremadura-oviedo
# honing-honed
# affirmation-affirm
# eloquently-plainly
# subjecting-depriving
# diaoyu-islets
# linkages-linkage
# vases-vase
# 2400-4000
# calming-soothing
# saviola-crespo
# ramnaresh-samuels
# faroe-andorra
# yosef-shlomo
# crewe-hereford
# lw-rw
# buthelezi-kwazulu
# anglesey-wight
# asda-tesco
# counterattacks-repelled
# indecisive-timid
# affirms-endorses
# stomped-trampled
# shi'ite-moqtada
# bouquets-bouquet
# krasnodar-novgorod
# bambi-godzilla
# fangs-claws
# parred-par-3
# buckles-buckle
# sligo-tipperary
# meteorite-meteor
# blenheim-marlborough
# v1-.0
# landon-beasley
# attainment-attaining
# campground-rv
# toothbrush-toothpaste
# 14th-century-romanesque
# liberally-generously
# 2004-2005-2008-09
# rebranded-relaunched
# repatriating-repatriate
# karni-erez
# simulators-simulator
# walmart-safeway
# snags-snag
# dunfermline-mirren
# paddling-kayak
# socio-economic-socioeconomic
# viewership-readership
# observant-religiously
# puree-blender
# 2.93-1.17
# 1.54-3.50
# hae-seung
# mckie-sixers
# devising-crafting
# sculpted-likeness
# puffs-puff
# dingell-markey
# stabilising-stabilise
# 84-year-56-year
# muttiah-spinners
# legalizing-legalization
# unequivocally-emphatically
# insensitivity-disrespect
# magnates-industrialists
# kickstart-moribund
# hollandsworth-gagne
# bolsters-reinforces
# preservationists-conservationists
# unsurprisingly-predictably
# liberalized-liberalisation
# microbes-germs
# disintegrating-disintegrated
# irrigated-acreage
# 536-262
# billick-holmgren
# dampening-spurring
# vocalists-djs
# reactivate-restarting
# improvise-improvisation
# authorising-authorizes
# hahb-brah
# erakat-qorei
# oriya-marathi
# 93rd-78th
# insulate-insulated
# pernambuco-bahia
# wither-vanish
# cashing-cashed
# eateries-boutiques
# teargas-canisters
# decrying-criticising
# cnpc-sinopec
# juggle-juggling
# gagged-blindfolded
# rancor-partisanship
# maelstrom-firestorm
# contemplation-solitude
# skyrocket-skyrocketed
# qui-je
# empties-descends
# berasategui-corretja
# uptick-upswing
# resiliency-perseverance
# gentler-kinder
# co-producer-co-produced
# farmlands-arable
# banknote-banknotes
# french-speaking-francophone
# narayan-dev
# rheumatoid-anemia
# isner-verdasco
# makelele-zinedine
# chevrontexaco-unocal
# ulithi-leyte
# instructs-instruct
# sufferings-untold
# duelfer-ekeus
# co-host-on-air
# gasol-pau
# polynesian-tahiti
# gaggle-throng
# 30.2-16.4
# 1.47-1.26
# hooligan-hooligans
# high-definition-simulcast
# rusted-mangled
# footbridge-viaduct
# amis-kingsley
# zoeller-crenshaw
# dependencies-falkland
# williamsport-harrisburg
# lourdes-fatima
# macclesfield-chesterfield
# bristles-brushes
# fd-tr
# sibelius-tchaikovsky
# smartphone-handset
# bogs-bog
# 9-8-9-7
# ascoli-lecce
# umaru-adua
# sassanid-assyrian
# circumstantial-anecdotal
# frederik-klerk
# d'état-d'etat
# oceanography-scripps
# h2-hummer
# 321-288
# nieminen-potro
# loong-kuan
# 1546-1441
# 568-630
# ogre-shrek
# residues-conserved
# voiceless-consonant
# ciro-ferrara

# %%
# print lean analogies
for (a,b,c) in lean_analogies:
    print(a+"-"+b)
# Out:
# ,-the
# 35.2-23.5
# cheddar-cheeses
# taoiseach-fianna
# evocative-descriptive
# stinking-filthy
# ridiculously-awfully
# potable-wastewater
# usair-ual
# laborious-painstaking
# 86-year-62-year
# millwall-brom
# 286-274
# welder-electrician
# marxists-anarchists
# domesticated-turkeys
# overline-sted
# beaujolais-nouveau
# aggressions-provocations
# abuzz-buzzing
# undead-zombies
# bjarne-csc
# mandolin-banjo
# solidifying-solidify
# boisterous-joyous
# peeking-poking
# reissues-reissue
# jogged-limped
# scooping-scooped
# overvalued-valuations
# muffled-audible
# 1563-1530
# 85-year-58-year
# photovoltaic-pv
# aqueous-acidic
# paraná-río
# 107th-81st
# newborns-toddlers
# ovaries-womb
# fossilized-footprints
# f-14-hornet
# horticulture-horticultural
# commutes-commuting
# silhouettes-silhouette
# signified-signifies
# santorum-brownback
# blizzards-snowstorm
# synonyms-synonym
# wariness-aversion
# otters-otter
# 355-239
# razzano-schiavone
# truffles-caviar
# fastened-strap
# sleigh-reindeer
# blackmailed-tricked
# diverging-divergent
# hilda-solis
# unflinching-uncompromising
# artfully-meticulously
# 1130-0900
# golovin-dokic
# tsb-rbs
# real-world-real-life
# demurred-hesitated
# vices-evils
# implantation-fertilization
# jarrod-washburn
# umbilical-cords
# livid-incensed
# vasser-indycar
# dior-hermes
# substandard-shoddy
# ebullient-boisterous
# tuqiri-brumbies
# 1715-1772
# kashgar-uygur
# campy-spoof
# interacted-interacting
# keem-rih
# infuse-infused
# shipwrecked-seamen
# faure-gnassingbe
# tangent-perpendicular
# doggedly-stubbornly
# anxieties-soothe
# '92-'96
# alkali-salts
# palme-d'or
# cagney-lacey
# diwaniyah-nasiriyah
# cafeterias-dormitories
# steamers-paddle
# ludacris-snoop
# apologise-apologizing
# two-year-old-sire
# tutors-mentors
# 2.97-0.26
# 2019-2017
# indefatigable-tireless
# ducal-princely
# infused-steeped
# haneya-zahar
# talmud-qur
# quartets-quintet
# 7-12-1-5
# nevis-kitts
# emmys-grammys
# entailed-entails
# jibril-dahlan
# tiberius-nero
# hyperactivity-bipolar
# bichette-helton
# abstaining-abstain
# estrangement-alienation
# ashkelon-sderot
# shakers-movers
# scented-aroma
# raccoons-foxes
# neb.-kerrey
# arugula-cilantro
# 2010-2011-2007-08
# fortuyn-pim
# saloons-brothels
# libertad-cerro
# despot-tyrant
# fillet-steaks
# drunkenness-disorderly
# 33.1-24.5
# libertarians-feminists
# cartoonish-caricature
# unremitting-unrelenting
# trainee-trainees
# britten-requiem
# aniston-affleck
# b.s.-bs
# assimilate-assimilation
# arranger-lyricist
# manet-monet
# ascertained-ascertain
# hanescu-gasquet
# deepak-chopra
# cosmodrome-kazakstan
# normalisation-normalize
# hsiao-hou
# recitals-recital
# infuriating-angering
# pituitary-glands
# drinker-drinkers
# hera-zeus
# midler-keaton
# nair-mira
# flips-flipping
# harpsichord-accordion
# bolsheviks-bolshevik
# o'gara-flyhalf
# curing-cures
# epoxy-resin
# apocryphal-gospels
# endocrine-gland
# castleford-warrington
# figurative-abstraction
# euro25-euro8
# aspired-aspire
# rhett-scarlett
# sturm-graz
# chiseled-sculpted
# 725-237
# carcinoma-ovarian
# possessive-adjective
# nudging-nudge
# approachable-likable
# cruzeiro-palmeiras
# druh-rahk
# swarms-hordes
# 270,000-34,000
# mattingly-boggs
# 4.40-1.27
# rooster-crows
# eskimos-cfl
# kilogrammes-hashish
# atchison-topeka
# unassailable-unbeatable
# delicately-subtly
# madan-mohan
# camdessus-wolfensohn
# exonerate-exonerated
# u-boats-battleships
# othello-macbeth
# 1500m-speedskating
# 26.95-7.50
# distaste-fondness
# torrents-deluge
# uncontrollable-uncontrolled
# fayetteville-ark.
# ajaccio-grenoble
# 106th-74th
# 405-720
# mascots-nicknames
# salacious-scandalous
# madeira-azores
# 609-244
# diligent-conscientious
# lps-eps
# enchanting-unforgettable
# mondale-dukakis
# ís-í
# 0.92-1.85
# frighten-dissuade
# springtime-summertime
# 0.36-1.18
# uyghur-turkic
# rags-rag
# envisage-foresees
# medford-ashland
# vuelta-d'italia
# widens-narrows
# 74th-73rd
# emits-consumes
# speeded-expedite
# maybank-bhd.
# persuades-begs
# neuronal-differentiation
# kamchatka-sakhalin
# seok-hwan
# unconscionable-egregious
# hurdler-400-meter
# resourceful-tenacious
# mildew-stains
# cornstarch-zest
# inserting-attaching
# defiantly-resolutely
# rubs-rubbed
# xing-xia
# goodell-tagliabue
# firebombs-lobbed
# secs-clocking
# horrifying-unimaginable
# delirious-giddy
# sykes-wanda
# prescribes-specifies
# diagnosing-diagnose
# syntactic-semantic
# nationalize-nationalization
# drugstores-pharmacists
# propellers-boilers
# artd-toder
# agility-durability
# vandalized-ransacked
# 12-10-tiebreak
# abilene-lubbock
# sabotaging-wrecking
# femme-nikita
# mountaineer-mountaineers
# prowl-roamed
# 2.54-1.16
# voip-handsets
# blinking-blink
# 16.4-14.2
# 463-261
# guimaraes-braga
# janica-ivica
# heartening-sobering
# obliquely-alluded
# popularizing-inventing
# 11-13-9-11
# petitioner-habeas
# sayings-quotations
# barged-sneaked
# grandstand-bleachers
# formula_7-α
# eilat-aqaba
# decayed-rotting
# compositional-stylistic
# provincetown-nantucket
# 13/16-1/16
# uhf-analogue
# mutilation-circumcision
# damping-vibration
# cingular-at&t
# harkin-baucus
# subsets-formula_6
# valedictorian-laude
# completions-tds
# fellowships-fulbright
# revolts-uprisings
# tue-thu
# wiesel-elie
# foresees-anticipates
# lowlands-grasslands
# 1.52-1.10
# tolerable-permissible
# practicality-usefulness
# levant-mesopotamia
# 99th-85th
# 22.95-hyperion
# connacht-ó
# dolce-vita
# allegiances-loyalties
# baran-yadav
# librarians-curators
# risque-suggestive
# oxidized-oxidation
# 3.21-1.14
# wil-cordero
# finalizing-finalised
# 1772-1774
# eunice-shriver
# eatery-deli
# stevenage-swindon
# camry-minivans
# unitarian-congregational
# anthropomorphic-mythological
# turrets-aft
# overflowed-overflowing
# rewrote-rewritten
# syrah-chardonnay
# modernised-overhauled
# worshipping-worshipped
# 430,000-42,000
# nimble-agile
# heartache-heartbreak
# confederates-repulsed
# federalists-federalist
# premiering-debuting
# fédération-internationale
# auditioning-auditioned
# razors-scissors
# platters-platter
# disquiet-apprehension
# unreasonably-unnecessarily
# terminates-terminating
# distinctively-strikingly
# chiu-tien
# bozize-deby
# preclude-entail
# translucent-opaque
# longest-running-long-running
# perishable-foodstuffs
# coinage-minted
# extremadura-oviedo
# honing-honed
# affirmation-affirm
# eloquently-plainly
# subjecting-depriving
# diaoyu-islets
# linkages-linkage
# vases-vase
# 2400-4000
# calming-soothing
# saviola-crespo
# ramnaresh-samuels
# faroe-andorra
# yosef-shlomo
# crewe-hereford
# lw-rw
# buthelezi-kwazulu
# anglesey-wight
# asda-tesco
# counterattacks-repelled
# indecisive-timid
# affirms-endorses
# stomped-trampled
# shi'ite-moqtada
# bouquets-bouquet
# krasnodar-novgorod
# bambi-godzilla
# fangs-claws
# parred-par-3
# buckles-buckle
# sligo-tipperary
# meteorite-meteor
# blenheim-marlborough
# v1-.0
# landon-beasley
# attainment-attaining
# campground-rv
# toothbrush-toothpaste
# 14th-century-romanesque
# liberally-generously
# 2004-2005-2008-09
# rebranded-relaunched
# repatriating-repatriate
# karni-erez
# simulators-simulator
# walmart-safeway
# snags-snag
# dunfermline-mirren
# paddling-kayak
# socio-economic-socioeconomic
# viewership-readership
# observant-religiously
# puree-blender
# 2.93-1.17
# 1.54-3.50
# hae-seung
# mckie-sixers
# devising-crafting
# sculpted-likeness
# puffs-puff
# dingell-markey
# stabilising-stabilise
# 84-year-56-year
# muttiah-spinners
# legalizing-legalization
# unequivocally-emphatically
# insensitivity-disrespect
# magnates-industrialists
# kickstart-moribund
# hollandsworth-gagne
# bolsters-reinforces
# preservationists-conservationists
# unsurprisingly-predictably
# liberalized-liberalisation
# microbes-germs
# disintegrating-disintegrated
# irrigated-acreage
# 536-262
# billick-holmgren
# dampening-spurring
# vocalists-djs
# reactivate-restarting
# improvise-improvisation
# authorising-authorizes
# hahb-brah
# erakat-qorei
# oriya-marathi
# 93rd-78th
# insulate-insulated
# pernambuco-bahia
# wither-vanish
# cashing-cashed
# eateries-boutiques
# teargas-canisters
# decrying-criticising
# cnpc-sinopec
# juggle-juggling
# gagged-blindfolded
# rancor-partisanship
# maelstrom-firestorm
# contemplation-solitude
# skyrocket-skyrocketed
# qui-je
# empties-descends
# berasategui-corretja
# uptick-upswing
# resiliency-perseverance
# gentler-kinder
# co-producer-co-produced
# farmlands-arable
# banknote-banknotes
# french-speaking-francophone
# narayan-dev
# rheumatoid-anemia
# isner-verdasco
# makelele-zinedine
# chevrontexaco-unocal
# ulithi-leyte
# instructs-instruct
# sufferings-untold
# duelfer-ekeus
# co-host-on-air
# gasol-pau
# polynesian-tahiti
# gaggle-throng
# 30.2-16.4
# 1.47-1.26
# hooligan-hooligans
# high-definition-simulcast
# rusted-mangled
# footbridge-viaduct
# amis-kingsley
# zoeller-crenshaw
# dependencies-falkland
# williamsport-harrisburg
# lourdes-fatima
# macclesfield-chesterfield
# bristles-brushes
# fd-tr
# sibelius-tchaikovsky
# smartphone-handset
# bogs-bog
# 9-8-9-7
# ascoli-lecce
# umaru-adua
# sassanid-assyrian
# circumstantial-anecdotal
# frederik-klerk
# d'état-d'etat
# oceanography-scripps
# h2-hummer
# 321-288
# nieminen-potro
# loong-kuan
# 1546-1441
# 568-630
# ogre-shrek
# residues-conserved
# voiceless-consonant
# ciro-ferrara

# %%
# load (modified) professions file
with open("./debiaswe/data/professions_parties.json", 'r') as f:
    professions = json.load(f)
profession_words = [p[0] for p in professions]

# show party bias in word vectors associated with professions
# sort by projection score in the direction of gender
# equivalent to Fig 1
sp = sorted([(E.v(w).dot(lean_direction), w) for w in profession_words])

print('Extreme democrat occupations')
print(sp[-20:])

print('\n\nExtreme republican occupations')
print(sp[0:20])

# This looks suspicious - liberal/dem professions are at end of alphabet, conserative/rep professions are at the beginning
# Out:
# Extreme democrat occupations
# [(0.0, 'trooper'), (0.0, 'trucker'), (0.0, 'trumpeter'), (0.0, 'tutor'), (0.0, 'tycoon'), (0.0, 'undersecretary'), (0.0, 'understudy'), (0.0, 'valedictorian'), (0.0, 'vice-chancellor'), (0.0, 'violinist'), (0.0, 'vocalist'), (0.0, 'waiter'), (0.0, 'waitress'), (0.0, 'warden'), (0.0, 'warrior'), (0.0, 'welder'), (0.0, 'worker'), (0.0, 'wrestler'), (0.0, 'writer'), (0.0, 'writer')]
#
#
# Extreme republican occupations
# [(0.0, 'accountant'), (0.0, 'acquaintance'), (0.0, 'actor'), (0.0, 'actress'), (0.0, 'addict'), (0.0, 'administrator'), (0.0, 'adventurer'), (0.0, 'advocate'), (0.0, 'aide'), (0.0, 'alderman'), (0.0, 'alter-ego'), (0.0, 'ambassador'), (0.0, 'analyst'), (0.0, 'anthropologist'), (0.0, 'archaeologist'), (0.0, 'archbishop'), (0.0, 'architect'), (0.0, 'artist'), (0.0, 'artiste'), (0.0, 'assassin')]
